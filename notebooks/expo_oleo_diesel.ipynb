# %%
import pandas as pd

# %%
# sheet_2 has infos about diesel oil
df = pd.read_excel('../data/vendas-combustiveis-2.xls', sheet_name='DPCache_m3_2')

# %%
df.isna().count()
# Out:
# COMBUSTÍVEL    1080
# ANO            1080
# REGIÃO         1080
# ESTADO         1080
# Jan            1080
# Fev            1080
# Mar            1080
# Abr            1080
# Mai            1080
# Jun            1080
# Jul            1080
# Ago            1080
# Set            1080
# Out            1080
# Nov            1080
# Dez            1080
# TOTAL          1080
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#                      COMBUSTÍVEL   ANO               REGIÃO  \
# 0          ÓLEO DIESEL S-10 (m3)  2013         REGIÃO NORTE
# 1          ÓLEO DIESEL S-10 (m3)  2013         REGIÃO NORTE
# 2          ÓLEO DIESEL S-10 (m3)  2013         REGIÃO NORTE
# 3          ÓLEO DIESEL S-10 (m3)  2013         REGIÃO NORTE
# 4          ÓLEO DIESEL S-10 (m3)  2013         REGIÃO NORTE
# ...                          ...   ...                  ...
# 1075  ÓLEO DIESEL (OUTROS ) (m3)  2020           REGIÃO SUL
# 1076  ÓLEO DIESEL (OUTROS ) (m3)  2020  REGIÃO CENTRO-OESTE
# 1077  ÓLEO DIESEL (OUTROS ) (m3)  2020  REGIÃO CENTRO-OESTE
# 1078  ÓLEO DIESEL (OUTROS ) (m3)  2020  REGIÃO CENTRO-OESTE
# 1079  ÓLEO DIESEL (OUTROS ) (m3)  2020  REGIÃO CENTRO-OESTE
#
#                   ESTADO       Jan        Fev        Mar        Abr  \
# 0               RONDÔNIA  81453.67   3517.600   3681.700   4700.670
# 1                   ACRE   1483.00  11202.000    363.000    410.000
# ...

# %%
df["COMBUSTÍVEL"].unique().tolist()
# Out:
# ['ÓLEO DIESEL S-10 (m3)',
#  'ÓLEO DIESEL S-500 (m3)',
#  'ÓLEO DIESEL S-1800 (m3)',
#  'ÓLEO DIESEL MARÍTIMO (m3)',
#  'ÓLEO DIESEL (OUTROS ) (m3)']

# %%
df.pivot_table(columns='ANO')
# Out:
# ANO             2013           2014           2015           2016  \
# Abr     60307.030133   51869.521304   74220.619089   42771.067719
# Ago    103042.568659   46918.026037   59548.764859   55401.134222
# Dez     55067.428119   75790.160533   45881.122133   56621.066363
# Fev     57914.928378   61586.290807   83617.536748   60852.872963
# Jan     59414.827452   79935.594993   64601.320622   47262.214711
# Jul     72093.750444   47566.584585   57625.915770   78313.392593
# Jun     79113.163859   65331.619778   76410.345452   61585.425015
# Mai     68309.729015   64599.689526  106746.732444   44390.281296
# Mar     51387.745874   62484.237052   60223.150044   53637.333881
# Nov     51672.244067   63265.247726   61079.130600   72553.080911
# Out     54968.282807   91070.507563   62269.542096  101563.857681
# Set     96582.815689   67083.028948   49706.534993   71488.632148
# TOTAL   57866.153415  111856.788763   45637.735104   57686.604541
#
# ...

# %%
# df[(df["COMBUSTÍVEL"].isin(['ÓLEO DIESEL MARÍTIMO (m3)','ÓLEO DIESEL S-10 (m3)'])) & (df['ESTADO'] == 'CEARÁ')].pivot_table(columns='ANO')
df[(df["COMBUSTÍVEL"].isin(['ÓLEO DIESEL MARÍTIMO (m3)','ÓLEO DIESEL S-10 (m3)'])) & (df['ESTADO'] == 'CEARÁ')]
# df[ (df['ESTADO'] == 'CEARÁ')].pivot_table(columns='ANO')
# df[ (df['COMBUSTÍVEL'] == 'ÓLEO DIESEL S-1800 (m3)')].pivot_table(columns='ANO',values='TOTAL')
# Out:
#                     COMBUSTÍVEL   ANO           REGIÃO ESTADO            Jan  \
# 9         ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORDESTE  CEARÁ   47724.922000
# 90    ÓLEO DIESEL MARÍTIMO (m3)  2013  REGIÃO NORDESTE  CEARÁ     400.000000
# 144       ÓLEO DIESEL S-10 (m3)  2014  REGIÃO NORDESTE  CEARÁ   61558.161000
# 225   ÓLEO DIESEL MARÍTIMO (m3)  2014  REGIÃO NORDESTE  CEARÁ     895.000000
# 279       ÓLEO DIESEL S-10 (m3)  2015  REGIÃO NORDESTE  CEARÁ   61183.030000
# 360   ÓLEO DIESEL MARÍTIMO (m3)  2015  REGIÃO NORDESTE  CEARÁ    1170.000000
# 414       ÓLEO DIESEL S-10 (m3)  2016  REGIÃO NORDESTE  CEARÁ   53310.252000
# 495   ÓLEO DIESEL MARÍTIMO (m3)  2016  REGIÃO NORDESTE  CEARÁ     725.000000
# 549       ÓLEO DIESEL S-10 (m3)  2017  REGIÃO NORDESTE  CEARÁ   66689.679367
# 630   ÓLEO DIESEL MARÍTIMO (m3)  2017  REGIÃO NORDESTE  CEARÁ    1130.000000
# 684       ÓLEO DIESEL S-10 (m3)  2018  REGIÃO NORDESTE  CEARÁ   56703.650000
# ...

# %%
df2 = pd.read_excel('../data/vendas-combustiveis-2.xls', sheet_name='DPCache_m3')

# %%
df2["COMBUSTÍVEL"].unique().tolist()
# Out:
# ['GASOLINA C (m3)',
#  'GASOLINA DE AVIAÇÃO (m3)',
#  'QUEROSENE ILUMINANTE (m3)',
#  'QUEROSENE DE AVIAÇÃO (m3)',
#  'ÓLEO DIESEL (m3)',
#  'ÓLEO COMBUSTÍVEL (m3)',
#  'ETANOL HIDRATADO (m3)',
#  'GLP (m3)']

# %%
df2[ (df2['COMBUSTÍVEL'] == 'ÓLEO DIESEL (m3)')].pivot_table(columns='ANO',values='TOTAL')
# Out:
# ANO             2000           2001           2002           2003  \
# TOTAL  407022.164444  188517.558259  177498.816333  271234.887111
#
# ANO             2004           2005           2006           2007  \
# TOTAL  218054.299667  140849.789444  170129.283222  221968.376057
#
# ANO             2008           2009  ...           2011           2012  \
# TOTAL  215635.075624  183777.263348  ...  247468.709541  367064.189097
#
# ANO             2013           2014           2015           2016  \
# TOTAL  651031.559444  298848.384444  290095.587254  401293.303111
#
# ANO             2017           2018           2019          2020
# TOTAL  310972.426691  192393.967481  240149.419444  358674.07775
#
# [1 rows x 21 columns]

# %%
ÓLEO DIESEL S-10 (m3)
